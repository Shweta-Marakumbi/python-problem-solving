# %%
myset={1,2,"sanjay",5.66,"rahul","ayush","ramesh","ankit","rishikesh"}
print(myset)
print(type(myset))
#print(myset[1])  set is not orderwise
# Out:
# {1, 2, 'ramesh', 'rahul', 5.66, 'ayush', 'ankit', 'rishikesh', 'sanjay'}
# <class 'set'>

# %%
myset={1,2,"sanjay",5.66,"rahul","ayush","ramesh","ankit","rishikesh"}
print(myset)
print(type(myset))
myset.add(60)
print(myset)
# Out:
# {1, 2, 'ramesh', 'rahul', 5.66, 'ayush', 'ankit', 'rishikesh', 'sanjay'}
# <class 'set'>
# {1, 2, 'ramesh', 'rahul', 5.66, 60, 'ayush', 'ankit', 'rishikesh', 'sanjay'}

# %%
myset={1,2,"sanjay",5.66,"rahul","ayush","ramesh","ankit","rishikesh"}
myset.discard(3)
print(myset)
# Out:
# {1, 2, 'ramesh', 'rahul', 5.66, 'ayush', 'ankit', 'rishikesh', 'sanjay'}

# %%
myset={1,2,"sanjay",5.66,"rahul","ayush","ramesh","ankit","rishikesh"}
myset.remove(2)
print(myset)
# Out:
# {1, 5.66, 'ayush', 'ramesh', 'ankit', 'sanjay', 'rahul', 'rishikesh'}

# %%
myset={10,20,30,40}
yourset={"shweta","jha"}
newset=myset.union(yourset)
print(newset)
# Out:
# {'jha', 20, 40, 10, 'shweta', 30}

# %%
myset={10,20,30,40}
yourset={10,50,60,30}
print(myset.intersection(yourset))
# Out:
# {10, 30}

# %%
#difference() method this will return the element
myset={10,20,30,40}
yourset={10,50,60,30}
print(myset.difference(yourset))
# Out:
# {40, 20}

# %%
myset={10,20,30,40}
print(myset.pop())
# Out:
# 40
