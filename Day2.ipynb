# %%
print(2+2)
print("2"+"2")
val1=int(input("Enter first value:"))
val2=int(input("Enter second value:"))
print(val1+val2)
# Out:
# 4
# 22
# Enter first value: 4
# Enter second value: 6
# 10

# %%
#int() used to convert integer
print(int(3.14))
#print(int(10+5j))
print(int(True))
print(int(False))
#print(int("4.22"))
print(int("4"))
#print(int("prashant"))
# Out:
# 3
# 1
# 0
# 4

# %%
#float() used to convert integer
print(float(3.14))
#print(int(10+5j))
print(float(True))
print(float(False))
print(float(4.22))
print(float("4"))
#print(int("prashant"))
# Out:
# 3.14
# 1.0
# 0.0
# 4.22
# 4.0

# %%
#bool() is used to convert
print(bool(0)) #False
print(bool(15)) #True
print(bool(3.14)) #True
print(bool(0.0)) #False
print(bool(2+2j)) #True
print(bool(0+0j)) #False
print(bool(-1)) #True
print(bool(False)) #False
print(bool(True)) #True
print(bool(" ")) #True
# Out:
# False
# True
# True
# False
# True
# False
# True
# False
# True
# True

# %%
n=int(input("Enter any single digit:"))
if n>0:
    print("Positive number")
if n<0:
    print("Negative number")
if n==0:
    print("Zero")
# Out:
# Enter any single digit: 0
# Zero

# %%
#wap to accept 5 numbers in different variables and check maximum numbers
a=int(input("Enter first  numbers"))#6
b=int(input("Enter second  numbers")) #5
c=int(input("Enter third numbers")) #4
d=int(input("Enter fourth  numbers")) #2
e=int(input("Enter fifth numbers")) #1
print(a)
print(b)
print(c)
print(d)
print(e)
if a>b and a>c and a>d and a>e:
      print("a is max")
if b>a and b>c and b>d and b>e:
      print("b is max")
if c>a and c>b and c>d and c>e:
      print("c is max")
if d>a and d>b and d>c and d>e:
      prnit("d is max")
if e>a and e>b and e>c and e>d:
      print("e is max")
# Out:
# Enter first  numbers 6
# Enter second  numbers 5
# Enter third numbers 4
# Enter fourth  numbers 3
# Enter fifth numbers 2
# 6
# 5
# 4
# 3
# 2
# a is max

# %%
#wap to accept 3 paper marks and calculate total, percentage and if percentage is greater than or equal to 60 so he/she is eligible for placement drive
m1=int(input("Enter marks 1"))
m2=int(input("Enter marks 2"))
m3=int(input("Enter marks 3"))
total=m1+m2+m3
print(total)
percentage=total/3
print(percentage)
if percentage>60:
    print("eligible")
else:
    print("not")
# Out:
# Enter marks 1 70
# Enter marks 2 70
# Enter marks 3 70
# 210
# 70.0
# eligible

# %%
#wap to calculate simple interest
pa=int(input("Enter the principle amount"))
tm=int(input("Enter the time duration"))
r=int(input("Enter rate of interest "))
si=(pa*tm*r)/100
print("Simple interest" , si)
# Out:
# Enter the principle amount 100000
# Enter the time duration 1
# Enter rate of interest  10
# Simple interest 10000.0

# %%
h=float(input("Enter the height in feet"))
inch=h*12
cm=inch*2.54
print(inch)
print(cm)
# Out:
# Enter the height in feet 5
# 60.0
# 152.4

# %%
#wap for palindrame
num=123
print(num)
a=num%10
num=num//10
b=num%10
c=num//10
rev=a*100+b*10+c*1
print("Palindrome is",rev)
# Out:
# 123
# Palindrome is 321
