# %%
mylist=["prashant","ashish","komal","ankush","ashish",77,"sandip",60.52,"prashant"]
print(mylist)
print(type(mylist))
print(mylist[0])
print(mylist[1])
print(mylist[2])
print(mylist[-1])
print(mylist[2:5])
print(mylist[:5])
print(mylist[1:])
print(mylist[1:8:2])
print(mylist[:])
print(mylist[::-1])
# Out:
# ['prashant', 'ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']
# <class 'list'>
# prashant
# ashish
# komal
# prashant
# ['komal', 'ankush', 'ashish']
# ['prashant', 'ashish', 'komal', 'ankush', 'ashish']
# ['ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']
# ['ashish', 'ankush', 77, 60.52]
# ['prashant', 'ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']
# ['prashant', 60.52, 'sandip', 77, 'ashish', 'ankush', 'komal', 'ashish', 'prashant']

# %%
mylist[2]="akshay"
print(mylist)
# Out:
# ['prashant', 'ashish', 'akshay', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']

# %%
if "ankush" in mylist: #cheking whether value is present or not
    print("yes ankush is available")
else:
    print("not available")
# Out:
# yes ankush is available

# %%
mylist=["prashant","ashish","komal","ankush","ashish",77,"sandip",60.52,"prashant"]
mylist.append("asha") #adding values in list. it will add in last like stack
mylist.append("shweta")
print(mylist)
# Out:
# ['prashant', 'ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant', 'asha', 'shweta']

# %%
mylist=["prashant","ashish","komal","ankush","ashish",77,"sandip",60.52,"prashant"]
mylist.insert(1,"asha") #this function insert value in index1
print(mylist)
# Out:
# ['prashant', 'asha', 'ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']

# %%
mylist=["prashant","ashish","komal","ankush","ashish",77,"sandip",60.52,"prashant"]
print(mylist) 
mylist.remove("ashish") #it will remove the value
print(mylist)
# Out:
# ['prashant', 'ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']
# ['prashant', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']

# %%
mylist=["prashant","ashish","komal","ankush","ashish",77,"sandip",60.52,"prashant"]
newlist=mylist.copy() #cloning
print(mylist)
print(newlist)
# Out:
# ['prashant', 'ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']
# ['prashant', 'ashish', 'komal', 'ankush', 'ashish', 77, 'sandip', 60.52, 'prashant']

# %%
mylist=[['prashanth','jha'],['85.56'],[440022,"yyy"]]
print("example of multidimentional list:")
print(mylist)
#print(mylist[row][col]) #      0               1
print(mylist[0][0])      # 0=['prashanth'     'jha']
print(mylist[0][1])      # 1=['85.56']
print(mylist[1][0])      # 2=['440022'        'yyy']
print(mylist[2][0])
print(mylist[2][1])
# Out:
# example of multidimentional list:
# [['prashanth', 'jha'], ['85.56'], [440022, 'yyy']]
# prashanth
# jha
# 85.56
# 440022
# yyy

# %%
list1=['prashant','jha']
print(list1*6)
# Out:
# ['prashant', 'jha', 'prashant', 'jha', 'prashant', 'jha', 'prashant', 'jha', 'prashant', 'jha', 'prashant', 'jha']

# %%
list1=['prashant','jha']
list2=[50,25.50] #combaining 2 lists
print(list1+list2)
# Out:
# ['prashant', 'jha', 50, 25.5]

# %%
list2=['prashant', 'jha', 50, 25.5]
del list2[2]#deleting index value 2
#del list2
print(list2)
# Out:
# ['prashant', 'jha', 25.5]

# %%
v=[1,2,3,4,5]
for i in v:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
list3=['prashant', 'jha', 50, 25.5]
list3.clear() #deleting entire list
print(list3)
# Out:
# []

# %%
name="shweta" #str
print(name)
myname=list(name) #typecasting=converting str to list
print(myname)
# Out:
# shweta
# ['s', 'h', 'w', 'e', 't', 'a']

# %%
mylist=[40,30,20,10]
mylist.reverse()
print(mylist)
# Out:
# [10, 20, 30, 40]

# %%
mylist=[44,22,77,0,9,88]
mylist.sort()
print(mylist)
# Out:
# [0, 9, 22, 44, 77, 88]

# %%
mylist=[44,22,77,0,9,88]
mylist.sort(reverse=True)
print(mylist)
# Out:
# [88, 77, 44, 22, 9, 0]

# %%
mylist=[44,22,77,0,9,88]
newlist=mylist #address is same
print(id(mylist))
print(id(newlist))
# Out:
# 1436423515456
# 1436423515456

# %%
mytuple=("prashant","ashish","rahul","sandeep","komal","ankush","rajesh",23,3.15,77,"sandip")
print(mytuple)
print(type(mytuple))
print(id(mytuple))
#mytuple[2]="sunil" #tuple is immutable
print(mytuple)
# Out:
# ('prashant', 'ashish', 'rahul', 'sandeep', 'komal', 'ankush', 'rajesh', 23, 3.15, 77, 'sandip')
# <class 'tuple'>
# 2740530831808
# ('prashant', 'ashish', 'rahul', 'sandeep', 'komal', 'ankush', 'rajesh', 23, 3.15, 77, 'sandip')

# %%
print('x' in"shweta")
# Out:
# False

# %%
print('x' not in"shweta")
# Out:
# True

# %%
print('a' in"shweta")
# Out:
# True

# %%
mylist=[3,5,6,7,8]
print(10 in mylist)
# Out:
# False

# %%
a=10
b=15
print(id(a))
print(id(b))
print(a is b)
print(a is not b)
# Out:
# 140728866809032
# 140728866809192
# False
# True

# %%
a=10
b=10
print(id(a))
print(id(b))
print(a is b)
print(a is not b)
# Out:
# 140728866809032
# 140728866809032
# True
# False

# %%
phy=50
chem=60
math=70
print("physics={} chemistry={} math={}".format(phy,chem,math))
print("physics={0} chemistry={1} math={2}".format(phy,chem,math))
print("physics={x} chemistry={y} math={z}".format(x=phy,y=chem,z=math))
total=phy+chem+math
print("Total Marks",f"{total}")
print("Roll No=","7".zfill(4))
# Out:
# physics=50 chemistry=60 math=70
# physics=50 chemistry=60 math=70
# physics=50 chemistry=60 math=70
# Total Marks 180
# Roll No= 0007
